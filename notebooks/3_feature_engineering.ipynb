# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/unnatir/Desktop/ML/Food_Wastage_Prediction/data/raw/food_wastage_data.csv")

# %%
df=df.rename(columns={
    'Type of Food':'food_type',
    'Number of Guests':'num_guests',
    'Quantity of Food':'quantity_prepared',
    'Wastage Food Amount':'quantity_wasted',
    'Event Type':'event_type'
})
df.head()
# Out:
#     food_type  num_guests event_type  quantity_prepared Storage Conditions  \
# 0        Meat         310  Corporate                450       Refrigerated
# 1        Meat         400   Birthday                500   Room Temperature
# 2  Vegetables         302   Birthday                371       Refrigerated
# 3        Meat         491   Birthday                497       Refrigerated
# 4        Meat         300  Corporate                400       Refrigerated
#
#   Purchase History  Seasonality Preparation Method Geographical Location  \
# 0          Regular  All Seasons             Buffet                 Urban
# 1          Regular       Winter             Buffet              Suburban
# 2          Regular       Summer             Buffet              Suburban
# 3          Regular  All Seasons        Finger Food                 Rural
# 4          Regular       Winter        Finger Food                 Urban
#
#     Pricing  quantity_wasted
# 0       Low               25
# ...

# %%
df=df[df['quantity_prepared']>0]
df['waste_ratio']=df['quantity_wasted']/df['quantity_prepared']
df.head()
# Out:
#     food_type  num_guests event_type  quantity_prepared Storage Conditions  \
# 0        Meat         310  Corporate                450       Refrigerated
# 1        Meat         400   Birthday                500   Room Temperature
# 2  Vegetables         302   Birthday                371       Refrigerated
# 3        Meat         491   Birthday                497       Refrigerated
# 4        Meat         300  Corporate                400       Refrigerated
#
#   Purchase History  Seasonality Preparation Method Geographical Location  \
# 0          Regular  All Seasons             Buffet                 Urban
# 1          Regular       Winter             Buffet              Suburban
# 2          Regular       Summer             Buffet              Suburban
# 3          Regular  All Seasons        Finger Food                 Rural
# 4          Regular       Winter        Finger Food                 Urban
#
#     Pricing  quantity_wasted  waste_ratio
# ...

# %%
df['waste_per_guest']=df['quantity_wasted']/df['num_guests']

# %%
df_encoded=pd.get_dummies(
    df,
    columns=['food_type','event_type'],
    drop_first=True
)
df_encoded.head()
# Out:
#    num_guests  quantity_prepared Storage Conditions Purchase History  \
# 0         310                450       Refrigerated          Regular
# 1         400                500   Room Temperature          Regular
# 2         302                371       Refrigerated          Regular
# 3         491                497       Refrigerated          Regular
# 4         300                400       Refrigerated          Regular
#
#    Seasonality Preparation Method Geographical Location   Pricing  \
# 0  All Seasons             Buffet                 Urban       Low
# 1       Winter             Buffet              Suburban      High
# 2       Summer             Buffet              Suburban       Low
# 3  All Seasons        Finger Food                 Rural      High
# 4       Winter        Finger Food                 Urban  Moderate
#
#    quantity_wasted  waste_ratio  waste_per_guest  food_type_Dairy Products  \
# ...

# %%
y=df_encoded['quantity_wasted']
X=df_encoded.drop(columns=['quantity_wasted'])

# %%
df_encoded.to_csv("/Users/unnatir/Desktop/ML/Food_Wastage_Prediction/data/processed/food_waste_clean.csv")
